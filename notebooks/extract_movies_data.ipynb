# %% [markdown]
# # Extract Data
#
# #### In this notebook we will be extracting movie related information from the OMDB API and save a csv file with original kaggle dataset combined with newly collected data in one.
#
# 1. Data source: [Kaggle "Three decades of movies"](https://www.kaggle.com/danielgrijalvas/movies)
# 2. API source: [OMDB API](http://www.omdbapi.com/)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import json
import random
from pprint import pprint
from config import LOCAL_API_KEY
import time

# %%
# Visualize more columns
pd.options.display.max_columns = None

# %% [markdown]
# ## Initial clean of the downloaded CSV

# %%
# Import downloaded CSV which contains a list 6820 movies
file_path = '../resources/raw_data/movies.csv'
kaggle_df = pd.read_csv(file_path, sep=',', engine='python')
kaggle_df.head()
# Out:
#        budget                                 company country        director  \
# 0   8000000.0           Columbia Pictures Corporation     USA      Rob Reiner
# 1   6000000.0                      Paramount Pictures     USA     John Hughes
# 2  15000000.0                      Paramount Pictures     USA      Tony Scott
# 3  18500000.0  Twentieth Century Fox Film Corporation     USA   James Cameron
# 4   9000000.0                    Walt Disney Pictures     USA  Randal Kleiser
#
#        genre        gross                      name rating    released  \
# 0  Adventure   52287414.0               Stand by Me      R  1986-08-22
# 1     Comedy   70136369.0  Ferris Bueller's Day Off  PG-13  1986-06-11
# 2     Action  179800601.0                   Top Gun     PG  1986-05-16
# 3     Action   85160248.0                    Aliens      R  1986-07-18
# 4  Adventure   18564613.0   Flight of the Navigator     PG  1986-08-01
#
#    runtime  score               star   votes         writer  year
# 0       89    8.1        Wil Wheaton  299174   Stephen King  1986
# 1      103    7.8  Matthew Broderick  264740    John Hughes  1986
# 2      110    6.9         Tom Cruise  236909       Jim Cash  1986
# 3      137    8.4   Sigourney Weaver  540152  James Cameron  1986
# 4       90    6.9        Joey Cramer   36636  Mark H. Baker  1986

# %%
# Describe
kaggle_df.describe()
# Out:
#              budget         gross     runtime        score         votes  \
# count  6.820000e+03  6.820000e+03  6820.00000  6820.000000  6.820000e+03
# mean   2.458113e+07  3.349783e+07   106.55132     6.374897  7.121952e+04
# std    3.702254e+07  5.819760e+07    18.02818     1.003142  1.305176e+05
# min    0.000000e+00  7.000000e+01    50.00000     1.500000  2.700000e+01
# 25%    0.000000e+00  1.515839e+06    95.00000     5.800000  7.665250e+03
# 50%    1.100000e+07  1.213568e+07   102.00000     6.400000  2.589250e+04
# 75%    3.200000e+07  4.006534e+07   115.00000     7.100000  7.581225e+04
# max    3.000000e+08  9.366622e+08   366.00000     9.300000  1.861666e+06
#
#               year
# count  6820.000000
# mean   2001.000293
# std       8.944501
# min    1986.000000
# 25%    1993.000000
# 50%    2001.000000
# 75%    2009.000000
# max    2016.000000

# %%
# Number of rows
len(kaggle_df)
# Out:
# 6820

# %%
# Rename a few columns to make distinctions between the Kaggle CSV and dimensions
# scraped from the OMDB API
renamed_df = kaggle_df.rename(columns={'country': 'country_kaggle',
                                       'genre': 'genre_kaggle',
                                       'writer': 'writer_kaggle',
                                       'star': 'star_kaggle',
                                       'company': 'production',
                                       'score': 'score_imdb',
                                       'votes': 'votes_imdb'})
renamed_df.head(2)
# Out:
#       budget                     production country_kaggle     director  \
# 0  8000000.0  Columbia Pictures Corporation            USA   Rob Reiner
# 1  6000000.0             Paramount Pictures            USA  John Hughes
#
#   genre_kaggle       gross                      name rating    released  \
# 0    Adventure  52287414.0               Stand by Me      R  1986-08-22
# 1       Comedy  70136369.0  Ferris Bueller's Day Off  PG-13  1986-06-11
#
#    runtime  score_imdb        star_kaggle  votes_imdb writer_kaggle  year
# 0       89         8.1        Wil Wheaton      299174  Stephen King  1986
# 1      103         7.8  Matthew Broderick      264740   John Hughes  1986

# %%
new_df = renamed_df.copy()

# Add empty columns for dimensions we are going to scrape from OMDB API
new_df['genres_omdb'] = ''
new_df['writers_omdb'] = ''
new_df['actors_omdb'] = ''
new_df['plot'] = ''
new_df['language_omdb'] = ''
new_df['country_omdb'] = ''
new_df['awards'] = ''
new_df['poster'] = ''
new_df['score_metacritic'] = ''
new_df['type'] = ''

new_df.head(2)
# Out:
#       budget                     production country_kaggle     director  \
# 0  8000000.0  Columbia Pictures Corporation            USA   Rob Reiner
# 1  6000000.0             Paramount Pictures            USA  John Hughes
#
#   genre_kaggle       gross                      name rating    released  \
# 0    Adventure  52287414.0               Stand by Me      R  1986-08-22
# 1       Comedy  70136369.0  Ferris Bueller's Day Off  PG-13  1986-06-11
#
#    runtime  score_imdb        star_kaggle  votes_imdb writer_kaggle  year  \
# 0       89         8.1        Wil Wheaton      299174  Stephen King  1986
# 1      103         7.8  Matthew Broderick      264740   John Hughes  1986
#
#   genres_omdb writers_omdb actors_omdb plot language_omdb country_omdb awards  \
# 0
# 1
#
#   poster score_metacritic type
# 0
# 1

# %% [markdown]
# ## Perform API Calls to OMDB API
#
# And save extracted information in the dataframe

# %%
# Set up API key for requests
api_key = LOCAL_API_KEY

# %%
# Use the lat/lng we recovered to identify airports

print('Beginning Data Retrieval...')
print('-----------------------------')
    
for index, row in new_df.iterrows():

    # Use a new movie name for each new api call
    movie_name = new_df.loc[index, 'name']

    # Use the search term: 'International Airport' and our lat/lng
    query_url = f'http://www.omdbapi.com/?apikey={api_key}&t={movie_name}&plot=full'

    # make request to url and conver to json
    api_data = requests.get(query_url).json()
    
    # Build some mechanisms to better 
    if index % 100 == 0:
            print(f'Processing Movie Index #{index}')
            
    if index % 250 == 0:
        time.sleep(10)
    
    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        new_df.loc[index, 'genres_omdb'] = api_data['Genre']
        new_df.loc[index, 'writers_omdb'] = api_data['Writer']
        new_df.loc[index, 'actors_omdb'] = api_data['Actors']
        new_df.loc[index, 'plot'] = api_data['Plot']
        new_df.loc[index, 'language_omdb'] = api_data['Language']
        new_df.loc[index, 'country_omdb'] = api_data['Country']
        new_df.loc[index, 'awards'] = api_data['Awards']
        new_df.loc[index, 'poster'] = api_data['Poster']
        new_df.loc[index, 'score_metacritic'] = api_data['Metascore']
        new_df.loc[index, 'type'] = api_data['Type']
        
    except (KeyError, IndexError):
        print('Missing field/result... skipping.')

print('-----------------------------')
print('Data Retrieval Complete.') 
print('-----------------------------')
# Out:
# Beginning Data Retrieval...
# -----------------------------
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Processing Movie Index #6700
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Processing Movie Index #6800
# Missing field/result... skipping.
# -----------------------------
# Data Retrieval Complete.
# -----------------------------

# %%
new_df
# Out:
#           budget                              production country_kaggle  \
# 0      8000000.0           Columbia Pictures Corporation            USA
# 1      6000000.0                      Paramount Pictures            USA
# 2     15000000.0                      Paramount Pictures            USA
# 3     18500000.0  Twentieth Century Fox Film Corporation            USA
# 4      9000000.0                    Walt Disney Pictures            USA
# ...          ...                                     ...            ...
# 6815         0.0                Fox Searchlight Pictures             UK
# 6816         0.0                Siempre Viva Productions            USA
# 6817   3500000.0                  Warner Bros. Animation            USA
# 6818         0.0                     Borderline Presents            USA
# 6819         0.0               Les Productions du Tr�sor         France
#
#              director genre_kaggle        gross  \
# 0          Rob Reiner    Adventure   52287414.0
# 1         John Hughes       Comedy   70136369.0
# 2          Tony Scott       Action  179800601.0
# 3       James Cameron       Action   85160248.0
# 4      Randal Kleiser    Adventure   18564613.0
# ...               ...          ...          ...
# 6815  Mandie Fletcher       Comedy    4750497.0
# 6816   Paul Duddridge        Drama      28368.0
# 6817          Sam Liu    Animation    3775000.0
# 6818    Nicolas Pesce        Drama      25981.0
# 6819    Nicole Garcia        Drama      37757.0
#
#                                 name rating    released  runtime  score_imdb  \
# 0                        Stand by Me      R  1986-08-22       89         8.1
# 1           Ferris Bueller's Day Off  PG-13  1986-06-11      103         7.8
# 2                            Top Gun     PG  1986-05-16      110         6.9
# 3                             Aliens      R  1986-07-18      137         8.4
# 4            Flight of the Navigator     PG  1986-08-01       90         6.9
# ...                              ...    ...         ...      ...         ...
# 6815  Absolutely Fabulous: The Movie      R  2016-07-22       91         5.4
# 6816           Mothers and Daughters  PG-13  2016-05-06       90         4.9
# 6817        Batman: The Killing Joke      R  2016-07-25       76         6.5
# 6818           The Eyes of My Mother      R  2016-12-02       76         6.2
# 6819       From the Land of the Moon      R  2017-07-28      120         6.7
#
#             star_kaggle  votes_imdb      writer_kaggle  year  \
# 0           Wil Wheaton      299174       Stephen King  1986
# 1     Matthew Broderick      264740        John Hughes  1986
# 2            Tom Cruise      236909           Jim Cash  1986
# 3      Sigourney Weaver      540152      James Cameron  1986
# 4           Joey Cramer       36636      Mark H. Baker  1986
# ...                 ...         ...                ...   ...
# 6815  Jennifer Saunders        9161  Jennifer Saunders  2016
# 6816        Selma Blair        1959      Paige Cameron  2016
# 6817       Kevin Conroy       36333    Brian Azzarello  2016
# 6818     Kika Magalh�es        6947      Nicolas Pesce  2016
# 6819   Marion Cotillard        2411        Milena Agus  2016
#
#                                     genres_omdb  \
# 0                              Adventure, Drama
# 1                                        Comedy
# 2                                 Action, Drama
# 3           Action, Adventure, Sci-Fi, Thriller
# 4             Adventure, Comedy, Family, Sci-Fi
# ...                                         ...
# 6815                              Comedy, Crime
# 6816                                      Drama
# 6817  Animation, Action, Crime, Drama, Thriller
# 6818                    Drama, Horror, Thriller
# 6819
#
#                                            writers_omdb  \
# 0     Stephen King (novel), Raynold Gideon (screenpl...
# 1                                           John Hughes
# 2     Jim Cash, Jack Epps Jr., Ehud Yonay (magazine ...
# 3     James Cameron (story by), David Giler (story b...
# 4     Mark H. Baker (story), Michael Burton (screenp...
# ...                                                 ...
# 6815                     Jennifer Saunders (screenplay)
# 6816                      Paige Cameron, Paul Duddridge
# 6817  Brian Azzarello, Brian Bolland (based on the g...
# 6818                                      Nicolas Pesce
# 6819
#
#                                             actors_omdb  \
# 0     Wil Wheaton, River Phoenix, Corey Feldman, Jer...
# 1     Matthew Broderick, Alan Ruck, Mia Sara, Jeffre...
# 2     Tom Cruise, Kelly McGillis, Val Kilmer, Anthon...
# 3     Sigourney Weaver, Carrie Henn, Michael Biehn, ...
# 4     Joey Cramer, Paul Reubens, Cliff De Young, Ver...
# ...                                                 ...
# 6815  Lulu, Gwendoline Christie, Jennifer Saunders, ...
# 6816               Selma Blair, Luke Mitchell, Symmetry
# 6817   Kevin Conroy, Mark Hamill, Tara Strong, Ray Wise
# 6818  Diana Agostini, Olivia Bond, Will Brill, Joey ...
# 6819
#
#                                                    plot        language_omdb  \
# 0     It's the summer of 1959 in Castlerock, Oregon ...              English
# 1     High school student Ferris Bueller wants a day...      English, German
# 2     Lieutenant Pete "Maverick" Mitchell is an expe...              English
# 3     Fifty seven years after Ellen Ripley survived ...              English
# 4     A 12-year-old boy goes missing in 1978, only t...              English
# ...                                                 ...                  ...
# 6815  Edina and Patsy are still oozing glitz and gla...      English, French
# 6816  Interwoven stories of what it is to be a mom s...              English
# 6817  As Batman hunts for the escaped Joker, the Clo...              English
# 6818  In their secluded farmhouse, a mother, formerl...  English, Portuguese
# 6819
#
#        country_omdb                                             awards  \
# 0               USA  Nominated for 1 Oscar. Another 5 wins & 10 nom...
# 1               USA      Nominated for 1 Golden Globe. Another 2 wins.
# 2               USA      Won 1 Oscar. Another 10 wins & 5 nominations.
# 3           UK, USA    Won 2 Oscars. Another 18 wins & 23 nominations.
# 4               USA                                     4 nominations.
# ...             ...                                                ...
# 6815        UK, USA                             1 win & 7 nominations.
# 6816  United States                              1 win & 2 nominations
# 6817            USA                             1 win & 2 nominations.
# 6818            USA                           5 wins & 14 nominations.
# 6819
#
#                                                  poster score_metacritic  \
# 0     https://m.media-amazon.com/images/M/MV5BODJmY2...               75
# 1     https://m.media-amazon.com/images/M/MV5BMDA0Nj...               61
# 2     https://m.media-amazon.com/images/M/MV5BZjQxYT...               50
# 3     https://m.media-amazon.com/images/M/MV5BZGU2OG...               84
# 4     https://m.media-amazon.com/images/M/MV5BMjUwNm...               64
# ...                                                 ...              ...
# 6815  https://m.media-amazon.com/images/M/MV5BMjI4ND...               59
# 6816  https://m.media-amazon.com/images/M/MV5BNDQyMD...               29
# 6817  https://m.media-amazon.com/images/M/MV5BMTdjZT...              N/A
# 6818  https://m.media-amazon.com/images/M/MV5BMTcyMD...               63
# 6819
#
#        type
# 0     movie
# 1     movie
# 2     movie
# 3     movie
# 4     movie
# ...     ...
# 6815  movie
# 6816  movie
# 6817  movie
# 6818  movie
# 6819
#
# [6820 rows x 25 columns]

# %%
# Testing...
# ........

# Request data
movie= 'The Men Who Stare at Goats'
test_url = f'http://www.omdbapi.com/?apikey={api_key}&t={movie}&plot=full'
response = requests.get(test_url)
data = response.json()

pprint(data)
# Out:
# {'Actors': 'Ewan McGregor, George Clooney, Kevin Spacey',
#  'Awards': '1 win & 1 nomination',
#  'BoxOffice': '$32,428,195',
#  'Country': 'United States, United Kingdom',
#  'DVD': '31 Mar 2017',
#  'Director': 'Grant Heslov',
#  'Genre': 'Comedy, War',
#  'Language': 'English, Arabic',
#  'Metascore': '54',
#  'Plot': 'A reporter, trying to lose himself in the romance of war after his '
#          'marriage fails, gets more than he bargains for when he meets a '
#          'special forces agent who reveals the existence of a secret, psychic '
#          'military unit whose goal is to end war as we know it. The founder of '
#          'the unit has gone missing and the trail leads to another psychic '
#          'soldier who has distorted the mission to serve his own ends.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjIwOTQwNzg1MV5BMl5BanBnXkFtZTcwODc4MDU4Mg@@._V1_SX300.jpg',
#  'Production': 'Smoke House, Paul Lister',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '51%'},
#              {'Source': 'Metacritic', 'Value': '54/100'}],
#  'Released': '06 Nov 2009',
#  'Response': 'True',
#  'Runtime': '94 min',
#  'Title': 'The Men Who Stare at Goats',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'Jon Ronson, Peter Straughan',
#  'Year': '2009',
#  'imdbID': 'tt1234548',
#  'imdbRating': '6.2',
#  'imdbVotes': '128,321'}

# %%
pprint(data)
# Out:
# {'Actors': 'Jeff Goldblum, Geena Davis, John Getz, Joy Boushel',
#  'Awards': 'Won 1 Oscar. Another 6 wins & 10 nominations.',
#  'BoxOffice': '$40,456,565',
#  'Country': 'USA, UK, Canada',
#  'DVD': '25 Nov 2015',
#  'Director': 'David Cronenberg',
#  'Genre': 'Drama, Horror, Sci-Fi',
#  'Language': 'English',
#  'Metascore': '79',
#  'Plot': 'Seth Brundle (Jeff Goldblum), a brilliant but eccentric scientist '
#          'attempts to woo investigative journalist Veronica Quaife (Geena '
#          'Davis) by offering her a scoop on his latest research in the field '
#          'of matter transportation, which against all the expectations of the '
#          'scientific establishment have proved successful. Up to a point. '
#          'Brundle thinks he has ironed out the last problem when he '
#          'successfully transports a living creature, but when he attempts to '
#          'teleport himself a fly enters one of the transmission booths, and '
#          'Brundle finds he is a changed man. This Science-Gone-Mad film is the '
#          'source of the quotable quote "Be afraid. Be very afraid."',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BODcxMGMwOGEtMDUxMi00MzE5LTg4YTYtYjk1YjA4MzQxNTNlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_SX300.jpg',
#  'Production': 'SLM Production Group',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.6/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '92%'},
#              {'Source': 'Metacritic', 'Value': '79/100'}],
#  'Released': '15 Aug 1986',
#  'Response': 'True',
#  'Runtime': '96 min',
#  'Title': 'The Fly',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'George Langelaan (short story), Charles Edward Pogue (screenplay), '
#            'David Cronenberg (screenplay)',
#  'Year': '1986',
#  'imdbID': 'tt0091064',
#  'imdbRating': '7.6',
#  'imdbVotes': '163,112'}

# %% [markdown]
# ## Now we export the new dataframe with newly collected columns

# %%
# Export new dataset to CSV
final_df = new_df.copy()
final_df.to_csv('../resources/cleaned_data/movies_complete.csv', index=False)

# %%
final_df
# Out:
#           budget                              production country_kaggle  \
# 0      8000000.0           Columbia Pictures Corporation            USA
# 1      6000000.0                      Paramount Pictures            USA
# 2     15000000.0                      Paramount Pictures            USA
# 3     18500000.0  Twentieth Century Fox Film Corporation            USA
# 4      9000000.0                    Walt Disney Pictures            USA
# ...          ...                                     ...            ...
# 6815         0.0                Fox Searchlight Pictures             UK
# 6816         0.0                Siempre Viva Productions            USA
# 6817   3500000.0                  Warner Bros. Animation            USA
# 6818         0.0                     Borderline Presents            USA
# 6819         0.0               Les Productions du Tr�sor         France
#
#              director genre_kaggle        gross  \
# 0          Rob Reiner    Adventure   52287414.0
# 1         John Hughes       Comedy   70136369.0
# 2          Tony Scott       Action  179800601.0
# 3       James Cameron       Action   85160248.0
# 4      Randal Kleiser    Adventure   18564613.0
# ...               ...          ...          ...
# 6815  Mandie Fletcher       Comedy    4750497.0
# 6816   Paul Duddridge        Drama      28368.0
# 6817          Sam Liu    Animation    3775000.0
# 6818    Nicolas Pesce        Drama      25981.0
# 6819    Nicole Garcia        Drama      37757.0
#
#                                 name rating    released  runtime  score_imdb  \
# 0                        Stand by Me      R  1986-08-22       89         8.1
# 1           Ferris Bueller's Day Off  PG-13  1986-06-11      103         7.8
# 2                            Top Gun     PG  1986-05-16      110         6.9
# 3                             Aliens      R  1986-07-18      137         8.4
# 4            Flight of the Navigator     PG  1986-08-01       90         6.9
# ...                              ...    ...         ...      ...         ...
# 6815  Absolutely Fabulous: The Movie      R  2016-07-22       91         5.4
# 6816           Mothers and Daughters  PG-13  2016-05-06       90         4.9
# 6817        Batman: The Killing Joke      R  2016-07-25       76         6.5
# 6818           The Eyes of My Mother      R  2016-12-02       76         6.2
# 6819       From the Land of the Moon      R  2017-07-28      120         6.7
#
#             star_kaggle  votes_imdb      writer_kaggle  year  \
# 0           Wil Wheaton      299174       Stephen King  1986
# 1     Matthew Broderick      264740        John Hughes  1986
# 2            Tom Cruise      236909           Jim Cash  1986
# 3      Sigourney Weaver      540152      James Cameron  1986
# 4           Joey Cramer       36636      Mark H. Baker  1986
# ...                 ...         ...                ...   ...
# 6815  Jennifer Saunders        9161  Jennifer Saunders  2016
# 6816        Selma Blair        1959      Paige Cameron  2016
# 6817       Kevin Conroy       36333    Brian Azzarello  2016
# 6818     Kika Magalh�es        6947      Nicolas Pesce  2016
# 6819   Marion Cotillard        2411        Milena Agus  2016
#
#                                     genres_omdb  \
# 0                              Adventure, Drama
# 1                                        Comedy
# 2                                 Action, Drama
# 3           Action, Adventure, Sci-Fi, Thriller
# 4             Adventure, Comedy, Family, Sci-Fi
# ...                                         ...
# 6815                              Comedy, Crime
# 6816                                      Drama
# 6817  Animation, Action, Crime, Drama, Thriller
# 6818                    Drama, Horror, Thriller
# 6819
#
#                                            writers_omdb  \
# 0     Stephen King (novel), Raynold Gideon (screenpl...
# 1                                           John Hughes
# 2     Jim Cash, Jack Epps Jr., Ehud Yonay (magazine ...
# 3     James Cameron (story by), David Giler (story b...
# 4     Mark H. Baker (story), Michael Burton (screenp...
# ...                                                 ...
# 6815                     Jennifer Saunders (screenplay)
# 6816                      Paige Cameron, Paul Duddridge
# 6817  Brian Azzarello, Brian Bolland (based on the g...
# 6818                                      Nicolas Pesce
# 6819
#
#                                             actors_omdb  \
# 0     Wil Wheaton, River Phoenix, Corey Feldman, Jer...
# 1     Matthew Broderick, Alan Ruck, Mia Sara, Jeffre...
# 2     Tom Cruise, Kelly McGillis, Val Kilmer, Anthon...
# 3     Sigourney Weaver, Carrie Henn, Michael Biehn, ...
# 4     Joey Cramer, Paul Reubens, Cliff De Young, Ver...
# ...                                                 ...
# 6815  Lulu, Gwendoline Christie, Jennifer Saunders, ...
# 6816               Selma Blair, Luke Mitchell, Symmetry
# 6817   Kevin Conroy, Mark Hamill, Tara Strong, Ray Wise
# 6818  Diana Agostini, Olivia Bond, Will Brill, Joey ...
# 6819
#
#                                                    plot        language_omdb  \
# 0     It's the summer of 1959 in Castlerock, Oregon ...              English
# 1     High school student Ferris Bueller wants a day...      English, German
# 2     Lieutenant Pete "Maverick" Mitchell is an expe...              English
# 3     Fifty seven years after Ellen Ripley survived ...              English
# 4     A 12-year-old boy goes missing in 1978, only t...              English
# ...                                                 ...                  ...
# 6815  Edina and Patsy are still oozing glitz and gla...      English, French
# 6816  Interwoven stories of what it is to be a mom s...              English
# 6817  As Batman hunts for the escaped Joker, the Clo...              English
# 6818  In their secluded farmhouse, a mother, formerl...  English, Portuguese
# 6819
#
#        country_omdb                                             awards  \
# 0               USA  Nominated for 1 Oscar. Another 5 wins & 10 nom...
# 1               USA      Nominated for 1 Golden Globe. Another 2 wins.
# 2               USA      Won 1 Oscar. Another 10 wins & 5 nominations.
# 3           UK, USA    Won 2 Oscars. Another 18 wins & 23 nominations.
# 4               USA                                     4 nominations.
# ...             ...                                                ...
# 6815        UK, USA                             1 win & 7 nominations.
# 6816  United States                              1 win & 2 nominations
# 6817            USA                             1 win & 2 nominations.
# 6818            USA                           5 wins & 14 nominations.
# 6819
#
#                                                  poster score_metacritic  \
# 0     https://m.media-amazon.com/images/M/MV5BODJmY2...               75
# 1     https://m.media-amazon.com/images/M/MV5BMDA0Nj...               61
# 2     https://m.media-amazon.com/images/M/MV5BZjQxYT...               50
# 3     https://m.media-amazon.com/images/M/MV5BZGU2OG...               84
# 4     https://m.media-amazon.com/images/M/MV5BMjUwNm...               64
# ...                                                 ...              ...
# 6815  https://m.media-amazon.com/images/M/MV5BMjI4ND...               59
# 6816  https://m.media-amazon.com/images/M/MV5BNDQyMD...               29
# 6817  https://m.media-amazon.com/images/M/MV5BMTdjZT...              N/A
# 6818  https://m.media-amazon.com/images/M/MV5BMTcyMD...               63
# 6819
#
#        type
# 0     movie
# 1     movie
# 2     movie
# 3     movie
# 4     movie
# ...     ...
# 6815  movie
# 6816  movie
# 6817  movie
# 6818  movie
# 6819
#
# [6820 rows x 25 columns]
