# %% [markdown]
# ## Plot Transformation into Features
# *   This notebook is to be ran within the google colabl environment
# *   Takes the plot of movies and tokenises them to be used in our data models.

# %%
import os
# Find the latest version of spark 3.0  from http://www-us.apache.org/dist/spark/ and enter as the spark version
# For example:
# spark_version = 'spark-3.0.2'
spark_version = 'spark-3.0.2'
os.environ['SPARK_VERSION']=spark_version

# Install Spark and Java
# !apt-get update
# !apt-get install openjdk-11-jdk-headless -qq > /dev/null
# !wget -q http://www-us.apache.org/dist/spark/$SPARK_VERSION/$SPARK_VERSION-bin-hadoop2.7.tgz
# !tar xf $SPARK_VERSION-bin-hadoop2.7.tgz
# !pip install -q findspark

# Set Environment Variables
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["SPARK_HOME"] = f"/content/{spark_version}-bin-hadoop2.7"

# Start a SparkSession
import findspark
findspark.init()
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:2 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:4 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Hit:5 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:7 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:8 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:9 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Ign:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:11 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:12 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:13 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Reading package lists... Done

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("plot_NLP").getOrCreate()

# %%
from pyspark import SparkFiles
import pandas as pd

url = "https://data-bootcamp-ztc.s3.amazonaws.com/movies_complete_cleaned.csv"
spark.sparkContext.addFile(url)

df = spark.read.option('header', 'true').csv(SparkFiles.get("movies_complete_cleaned.csv"), inferSchema=True, sep = ",")
df.show(10)
# Out:
# +--------------------+--------------------+------------------+-------+----------+----+-----+--------------+--------------------+--------------------+--------------------+-----------------+--------------------+--------------------+--------------------+--------------------+----------+----------+----------------+--------+------------+--------+--------------------+------+
# |                name|          production|          director|runtime|  released|year|month|country_kaggle|        country_omdb|         star_kaggle|         actors_omdb|    writer_kaggle|        writers_omdb|       language_omdb|                plot|              awards|score_imdb|votes_imdb|score_metacritic|  budget|genre_kaggle|   gross|         genres_omdb|rating|
# +--------------------+--------------------+------------------+-------+----------+----+-----+--------------+--------------------+--------------------+--------------------+-----------------+--------------------+--------------------+--------------------+--------------------+----------+----------+----------------+--------+------------+--------+--------------------+------+
# |                Gold| Black Bear Pictures|    Stephen Gaghan|    120|2017-01-27|2016|    1|           USA|                 USA| Matthew McConaughey|Matthew McConaugh...|  Patrick Massett|Patrick Massett, ...| English, Indonesian|With the sudden d...|1 win & 5 nominat...|       6.7|     32147|            49.0|20000000|   Adventure| 7222964|        Crime, Drama|     R|
# |          The Choice|Nicholas Sparks P...|         Ross Katz|    111|2016-02-05|2016|    2|           USA|       United States|     Benjamin Walker|Benjamin Walker, ...|       Bryan Sipe|Bryan Sipe, Nicho...|             English|In a small coasta...|       3 nominations|       6.6|     22972|            26.0|       0|       Drama|18709066|      Drama, Romance| PG-13|
# |Middle School: Th...|           CBS Films|        Steve Carr|     92|2016-10-07|2016|   10|           USA|       USA, Cambodia|       Griffin Gluck|Griffin Gluck, La...|     Chris Bowman|Chris Bowman (scr...|      English, Khmer|Imaginative quiet...|      5 nominations.|       6.1|      4556|            51.0| 8500000|   Animation|19985196|Animation, Comedy...|    PG|
# |    Midnight Special|        Warner Bros.|      Jeff Nichols|    112|2016-04-21|2016|    4|           USA|         USA, Greece|     Michael Shannon|Michael Shannon, ...|     Jeff Nichols|        Jeff Nichols|             English|Alton Meyer is a ...|3 wins & 14 nomin...|       6.7|     58549|            76.0|18000000|       Drama| 3707794|Drama, Mystery, S...| PG-13|
# |     A Monster Calls|Apaches Entertain...|       J.A. Bayona|    108|2017-01-06|2016|    1|            UK|      UK, Spain, USA|    Lewis MacDougall|Lewis MacDougall,...|     Patrick Ness|Patrick Ness (scr...|             English|The monster does ...|39 wins & 56 nomi...|       7.5|     49969|            76.0|43000000|       Drama| 3730982|Adventure, Drama,...| PG-13|
# |The Brothers Grimsby|Big Talk Productions|   Louis Leterrier|     83|2016-03-11|2016|    3|            UK|                null|   Sacha Baron Cohen|                null|Sacha Baron Cohen|                null|                null|                null|                null|       6.2|     67444|            null|35000000|      Action| 6864016|                null|     R|
# |Pride and Prejudi...|Cross Creek Pictures|       Burr Steers|    108|2016-02-05|2016|    2|           USA|United States, Un...|          Lily James|Lily James, Sam R...|      Burr Steers|Burr Steers, Jane...|English, Japanese...|The five highly t...|1 win & 3 nominat...|       5.8|     37491|            45.0|28000000|      Action|10907291|Action, Comedy, F...| PG-13|
# |Mike and Dave Nee...|Twentieth Century...|    Jake Szymanski|     98|2016-07-08|2016|    7|           USA|       United States|           Zac Efron|Zac Efron, Adam D...| Andrew Jay Cohen|Andrew Jay Cohen,...|English, Chinese,...|Hard-partying bro...|       4 nominations|       6.0|     61076|            51.0|33000000|   Adventure|46007113|     Comedy, Romance|     R|
# |             Snowden|Endgame Entertain...|      Oliver Stone|    134|2016-09-16|2016|    9|        France|United Kingdom, F...|Joseph Gordon-Levitt|Joseph Gordon-Lev...|Kieran Fitzgerald|Kieran Fitzgerald...|English, American...|SNOWDEN stars Jos...|4 wins & 7 nomina...|       7.3|     92094|            58.0|40000000|   Biography|21587519|Biography, Crime,...|     R|
# |             The Boy|Lakeshore Enterta...|William Brent Bell|     97|2016-01-22|2016|    1|           USA|United States, Ca...|        Lauren Cohan|Lauren Cohan, Rup...|    Stacey Menear|       Stacey Menear|             English|Greta, a young Am...|       6 nominations|       6.0|     55856|            42.0| 8000000|      Horror|35794166|Horror, Mystery, ...| PG-13|
# +--------------------+--------------------+------------------+-------+----------+----+-----+--------------+--------------------+--------------------+--------------------+-----------------+--------------------+--------------------+--------------------+--------------------+----------+----------+----------------+--------+------------+--------+--------------------+------+
# only showing top 10 rows

# %% [markdown]
# ## Transform DataFrame to fit review_rating table

# %%
plot_df = df.select(["name","plot"])
plot_df.show()
# Out:
# +--------------------+--------------------+
# |                name|                plot|
# +--------------------+--------------------+
# |                Gold|With the sudden d...|
# |          The Choice|In a small coasta...|
# |Middle School: Th...|Imaginative quiet...|
# |    Midnight Special|Alton Meyer is a ...|
# |     A Monster Calls|The monster does ...|
# |The Brothers Grimsby|                null|
# |Pride and Prejudi...|The five highly t...|
# |Mike and Dave Nee...|Hard-partying bro...|
# |             Snowden|SNOWDEN stars Jos...|
# |             The Boy|Greta, a young Am...|
# |Miracles from Heaven|MIRACLES FROM HEA...|
# |    D�a del atentado|                null|
# |            The Boss|A titan of indust...|
# |             Arrival|Linguistics profe...|
# |       Gods of Egypt|Set, the merciles...|
# |Warcraft: The Beg...|                null|
# |Everybody Wants S...|In Texas in the f...|
# |The Birth of a Na...|Two brothers, Phi...|
# | Presencia siniestra|                null|
# |                Goat|Reeling from a te...|
# +--------------------+--------------------+
# only showing top 20 rows

# %%
plot_df = plot_df.filter("plot IS NOT NULL")
plot_df.show()
# Out:
# +--------------------+--------------------+
# |                name|                plot|
# +--------------------+--------------------+
# |                Gold|With the sudden d...|
# |          The Choice|In a small coasta...|
# |Middle School: Th...|Imaginative quiet...|
# |    Midnight Special|Alton Meyer is a ...|
# |     A Monster Calls|The monster does ...|
# |Pride and Prejudi...|The five highly t...|
# |Mike and Dave Nee...|Hard-partying bro...|
# |             Snowden|SNOWDEN stars Jos...|
# |             The Boy|Greta, a young Am...|
# |Miracles from Heaven|MIRACLES FROM HEA...|
# |            The Boss|A titan of indust...|
# |             Arrival|Linguistics profe...|
# |       Gods of Egypt|Set, the merciles...|
# |Everybody Wants S...|In Texas in the f...|
# |The Birth of a Na...|Two brothers, Phi...|
# |                Goat|Reeling from a te...|
# |Miss Peregrine's ...|"When Jacob disco...|
# |            War Dogs|Two friends in th...|
# |            Deadpool|This is the origi...|
# |            The Void|When police offic...|
# +--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ## Create Data Pipeline

# %%
from pyspark.ml.feature import Tokenizer, StopWordsRemover, HashingTF, IDF
# Create all the features to the data set
tokenizer = Tokenizer(inputCol="plot", outputCol="token_text")
stopremove = StopWordsRemover(inputCol='token_text',outputCol='stop_tokens')
hashingTF = HashingTF(inputCol="token_text", outputCol='hash_token')
idf = IDF(inputCol='hash_token', outputCol='idf_token')

# %%
# from pyspark.ml.feature import VectorAssembler
# from pyspark.ml.linalg import Vector

# # Create feature vectors
# clean_up = VectorAssembler(inputCols=['idf_token', ''], outputCol='features')

# %%
# Create and run a data processing Pipeline
from pyspark.ml import Pipeline
data_prep_pipeline = Pipeline(stages=[tokenizer, stopremove, hashingTF, idf])

# %% [markdown]
# ## Transform DataFrame

# %%
#@title Default title text
# Fit and transform the pipeline
cleaner = data_prep_pipeline.fit(plot_df)
cleaned = cleaner.transform(plot_df)

# %%
# Show label of ham spame and resulting features
cleaned.select(['name', 'plot','idf_token']).show()
# Out:
# +--------------------+--------------------+--------------------+
# |                name|                plot|           idf_token|
# +--------------------+--------------------+--------------------+
# |                Gold|With the sudden d...|(262144,[3048,905...|
# |          The Choice|In a small coasta...|(262144,[5,11104,...|
# |Middle School: Th...|Imaginative quiet...|(262144,[3072,218...|
# |    Midnight Special|Alton Meyer is a ...|(262144,[429,9129...|
# |     A Monster Calls|The monster does ...|(262144,[4360,178...|
# |Pride and Prejudi...|The five highly t...|(262144,[5923,127...|
# |Mike and Dave Nee...|Hard-partying bro...|(262144,[7182,155...|
# |             Snowden|SNOWDEN stars Jos...|(262144,[12810,38...|
# |             The Boy|Greta, a young Am...|(262144,[14376,19...|
# |Miracles from Heaven|MIRACLES FROM HEA...|(262144,[61,9420,...|
# |            The Boss|A titan of indust...|(262144,[3280,942...|
# |             Arrival|Linguistics profe...|(262144,[24980,27...|
# |       Gods of Egypt|Set, the merciles...|(262144,[5944,680...|
# |Everybody Wants S...|In Texas in the f...|(262144,[13689,25...|
# |The Birth of a Na...|Two brothers, Phi...|(262144,[7862,127...|
# |                Goat|Reeling from a te...|(262144,[11104,23...|
# |Miss Peregrine's ...|"When Jacob disco...|(262144,[17893,18...|
# |            War Dogs|Two friends in th...|(262144,[1968,273...|
# |            Deadpool|This is the origi...|(262144,[429,6034...|
# |            The Void|When police offic...|(262144,[666,6872...|
# +--------------------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ## Export

# %%
from google.colab import  drive
import pandas as pd

drive.mount('/drive')

final_df = cleaned.select(['name', 'plot','idf_token']).toPandas()

final_df.to_csv('/drive/My Drive/BC/bc-data/finalproject/plot_features.csv', index = False)
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).
