# %%
import pandas as pd

# %%
movies = pd.read_csv(
    "https://data-bootcamp-ztc.s3.amazonaws.com/movies_complete_cleaned.csv"
)

awards = pd.read_csv(
    "https://data-bootcamp-ztc.s3.amazonaws.com/parsed_awards_table.csv"
)

features = pd.read_csv(
    "../../resources/cleaned_data/plot_features.csv"
)
movies_sel = movies[["name", "genre_kaggle"]]

awards_sel = awards[["name", "oscar wins and nominations"]]

features_sel = features[['name', 'plot', 'idf_token']]


df = pd.merge(pd.merge(movies_sel, awards_sel, how="right", on="name"), features_sel, how = "right", on ="name")

df["target"] = [1 if x != 0 else 0 for x in df["oscar wins and nominations"]] #binary where movie was oscar nominated

df = df[["name", "target","plot","idf_token","genre_kaggle"]]

df.set_index("name", inplace = True)

genre_encoded = pd.get_dummies(df.genre_kaggle, prefix = "genre")

df = pd.merge(df, genre_encoded, how = "right", on = "name")


df.head()
# Out:
#                        target  \
# name
# Doctor Strange              1
# Sleight                     0
# Silence                     1
# Manchester by the Sea       1
# Dirty Grandpa               0
#
#                                                                     plot  \
# name
# Doctor Strange         "Marvel's ""Doctor Strange"" follows the story...
# Sleight                A young street magician (Jacob Latimore) is le...
# Silence                The story of two Catholic missionaries (Andrew...
# Manchester by the Sea  Lee Chandler is a brooding, irritable loner wh...
# Dirty Grandpa          Jason Kelly, the grandson of Dick Kelly, loses...
#
#                                                                idf_token  \
# name
# Doctor Strange         (262144,[13977,50770,78295,111767,125169,12556...
# Sleight                (262144,[3329,6478,12915,16108,32890,36225,564...
# Silence                (262144,[4757,25337,26496,38640,64733,73707,93...
# ...

# %%
# X = 

y = df.target.values.reshape(-1,1)

# %%
X = df.drop(["target","plot","genre_kaggle"],axis = 1)
X

print(X.shape, y.shape)
# Out:
# (5914, 18) (5914, 1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression()

# %%
classifier.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-f44724590846> in <module>
# ----> 1 classifier.fit(X_train, y_train)
#
# /opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1344         X, y = self._validate_data(X, y, accept_sparse='csr', dtype=_dtype,
#    1345                                    order="C",
# -> 1346                                    accept_large_sparse=solver != 'liblinear')
#    1347         check_classification_targets(y)
#    1348         self.classes_ = np.unique(y)
#
# /opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# ...

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-39-c907d6baa5de> in <module>
# ----> 1 print(f"Training Data Score: {classifier.score(X_train, y_train)}")
#       2 print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
#
# /opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/sklearn/base.py in score(self, X, y, sample_weight)
#     498         """
#     499         from .metrics import accuracy_score
# --> 500         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     501
#     502     def _more_tags(self):
#
# /opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     307             Predicted class label per sample.
#     308         """
# --> 309         scores = self.decision_function(X)
#     310         if len(scores.shape) == 1:
# ...

# %%
type(df["idf_token"][0])
# Out:
# str

# %%
df["idf_token"][0].totuple()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-bece69edb56f> in <module>
# ----> 1 df["idf_token"][0].totuple()
#
# AttributeError: 'str' object has no attribute 'totuple'
