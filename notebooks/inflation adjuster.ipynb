# %%
import pandas as pd
import os

# %%
path = os.path.join('..','resources','cleaned_data', 'movies_complete_cleaned.csv')
df = pd.read_csv(path)
selected = ['name', 'year', 'budget', 'gross']
df = df[selected]
df
# Out:
#                                            name  year    budget      gross
# 0                                          Gold  2016  20000000    7222964
# 1                                    The Choice  2016         0   18709066
# 2     Middle School: The Worst Years of My Life  2016   8500000   19985196
# 3                              Midnight Special  2016  18000000    3707794
# 4                               A Monster Calls  2016  43000000    3730982
# ...                                         ...   ...       ...        ...
# 6550                     The Karate Kid Part II  1986         0  115103979
# 6551                                  Mona Lisa  1986         0    5794184
# 6552                            Ginger and Fred  1986         0     837623
# 6553                                   Critters  1986   2000000   13167232
# 6554             Poltergeist II: The Other Side  1986  19000000   40996665
#
# [6555 rows x 4 columns]

# %%
path = os.path.join('..','resources','raw_data', 'CPI_data.xlsx')
CPI = pd.read_excel(path)
CPI.head()
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-3-4d49d545b9a2> in <module>
#       1 path = os.path.join('..','resources','raw_data', 'CPI_data.xlsx')
# ----> 2 CPI = pd.read_excel(path)
#       3 CPI.head()
#
# /opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ...

# %%
CPI_new = CPI.loc(2021,"annual")


for i, row in df.iterrows():
    year_new = row[1]
    
    for year in CPI["year"]:
        if year == row[1]:
            CIP_old = CPI['annual']
            
    budget_new = row[2]*CPI_new/CPI_old
    gross_new =
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# ...
