# %% [markdown]
# # Transform/Clean Data
#
# #### In this notebook we will be cleaning the csv with the complete data we collected from the OMDB API. We decided to leave most of the columns untouched as we will perform further data preprocessing depending on selected models going forward.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
# Visualize more columns
pd.options.display.max_columns = None

# %%
# Import downloaded CSV which contains a list 6820 movies
file_path = '../resources/cleaned_data/movies_complete.csv'
movies_df = pd.read_csv(file_path)
movies_df.head()
# Out:
#        budget                              production country_kaggle  \
# 0   8000000.0           Columbia Pictures Corporation            USA
# 1   6000000.0                      Paramount Pictures            USA
# 2  15000000.0                      Paramount Pictures            USA
# 3  18500000.0  Twentieth Century Fox Film Corporation            USA
# 4   9000000.0                    Walt Disney Pictures            USA
#
#          director genre_kaggle        gross                      name rating  \
# 0      Rob Reiner    Adventure   52287414.0               Stand by Me      R
# 1     John Hughes       Comedy   70136369.0  Ferris Bueller's Day Off  PG-13
# 2      Tony Scott       Action  179800601.0                   Top Gun     PG
# 3   James Cameron       Action   85160248.0                    Aliens      R
# 4  Randal Kleiser    Adventure   18564613.0   Flight of the Navigator     PG
#
#      released  runtime  score_imdb        star_kaggle  votes_imdb  \
# 0  1986-08-22       89         8.1        Wil Wheaton      299174
# 1  1986-06-11      103         7.8  Matthew Broderick      264740
# 2  1986-05-16      110         6.9         Tom Cruise      236909
# 3  1986-07-18      137         8.4   Sigourney Weaver      540152
# 4  1986-08-01       90         6.9        Joey Cramer       36636
#
#    writer_kaggle  year                          genres_omdb  \
# 0   Stephen King  1986                     Adventure, Drama
# 1    John Hughes  1986                               Comedy
# 2       Jim Cash  1986                        Action, Drama
# 3  James Cameron  1986  Action, Adventure, Sci-Fi, Thriller
# 4  Mark H. Baker  1986    Adventure, Comedy, Family, Sci-Fi
#
#                                         writers_omdb  \
# 0  Stephen King (novel), Raynold Gideon (screenpl...
# 1                                        John Hughes
# 2  Jim Cash, Jack Epps Jr., Ehud Yonay (magazine ...
# 3  James Cameron (story by), David Giler (story b...
# 4  Mark H. Baker (story), Michael Burton (screenp...
#
#                                          actors_omdb  \
# 0  Wil Wheaton, River Phoenix, Corey Feldman, Jer...
# 1  Matthew Broderick, Alan Ruck, Mia Sara, Jeffre...
# 2  Tom Cruise, Kelly McGillis, Val Kilmer, Anthon...
# 3  Sigourney Weaver, Carrie Henn, Michael Biehn, ...
# 4  Joey Cramer, Paul Reubens, Cliff De Young, Ver...
#
#                                                 plot    language_omdb  \
# 0  It's the summer of 1959 in Castlerock, Oregon ...          English
# 1  High school student Ferris Bueller wants a day...  English, German
# 2  Lieutenant Pete "Maverick" Mitchell is an expe...          English
# 3  Fifty seven years after Ellen Ripley survived ...          English
# 4  A 12-year-old boy goes missing in 1978, only t...          English
#
#   country_omdb                                             awards  \
# 0          USA  Nominated for 1 Oscar. Another 5 wins & 10 nom...
# 1          USA      Nominated for 1 Golden Globe. Another 2 wins.
# 2          USA      Won 1 Oscar. Another 10 wins & 5 nominations.
# 3      UK, USA    Won 2 Oscars. Another 18 wins & 23 nominations.
# 4          USA                                     4 nominations.
#
#                                               poster  score_metacritic   type
# 0  https://m.media-amazon.com/images/M/MV5BODJmY2...              75.0  movie
# 1  https://m.media-amazon.com/images/M/MV5BMDA0Nj...              61.0  movie
# 2  https://m.media-amazon.com/images/M/MV5BZjQxYT...              50.0  movie
# 3  https://m.media-amazon.com/images/M/MV5BZGU2OG...              84.0  movie
# 4  https://m.media-amazon.com/images/M/MV5BMjUwNm...              64.0  movie

# %%
# movies_df['type'].value_counts()
movies_df.isna().sum()
# movies_df[movies_df['writers_omdb'].isnull()]
# Out:
# budget                 0
# production             0
# country_kaggle         0
# director               0
# genre_kaggle           0
# gross                  0
# name                   0
# rating                 0
# released               0
# runtime                0
# score_imdb             0
# star_kaggle            0
# votes_imdb             0
# writer_kaggle          0
# year                   0
# genres_omdb          349
# writers_omdb         414
# actors_omdb          365
# plot                 399
# language_omdb        359
# country_omdb         348
# awards              1435
# poster               390
# score_metacritic    1824
# type                 345
# dtype: int64

# %%
movies_df.head(2)
# Out:
#       budget                     production country_kaggle     director  \
# 0  8000000.0  Columbia Pictures Corporation            USA   Rob Reiner
# 1  6000000.0             Paramount Pictures            USA  John Hughes
#
#   genre_kaggle       gross                      name rating    released  \
# 0    Adventure  52287414.0               Stand by Me      R  1986-08-22
# 1       Comedy  70136369.0  Ferris Bueller's Day Off  PG-13  1986-06-11
#
#    runtime  score_imdb        star_kaggle  votes_imdb writer_kaggle  year  \
# 0       89         8.1        Wil Wheaton      299174  Stephen King  1986
# 1      103         7.8  Matthew Broderick      264740   John Hughes  1986
#
#         genres_omdb                                       writers_omdb  \
# 0  Adventure, Drama  Stephen King (novel), Raynold Gideon (screenpl...
# 1            Comedy                                        John Hughes
#
#                                          actors_omdb  \
# 0  Wil Wheaton, River Phoenix, Corey Feldman, Jer...
# 1  Matthew Broderick, Alan Ruck, Mia Sara, Jeffre...
#
#                                                 plot    language_omdb  \
# 0  It's the summer of 1959 in Castlerock, Oregon ...          English
# 1  High school student Ferris Bueller wants a day...  English, German
#
#   country_omdb                                             awards  \
# 0          USA  Nominated for 1 Oscar. Another 5 wins & 10 nom...
# 1          USA      Nominated for 1 Golden Globe. Another 2 wins.
#
#                                               poster  score_metacritic   type
# 0  https://m.media-amazon.com/images/M/MV5BODJmY2...              75.0  movie
# 1  https://m.media-amazon.com/images/M/MV5BMDA0Nj...              61.0  movie

# %%
# Check data types
movies_df.dtypes
# Out:
# budget              float64
# production           object
# country_kaggle       object
# director             object
# genre_kaggle         object
# gross               float64
# name                 object
# rating               object
# released             object
# runtime               int64
# score_imdb          float64
# star_kaggle          object
# votes_imdb            int64
# writer_kaggle        object
# year                  int64
# genres_omdb          object
# writers_omdb         object
# actors_omdb          object
# plot                 object
# language_omdb        object
# country_omdb         object
# awards               object
# poster               object
# score_metacritic    float64
# type                 object
# dtype: object

# %%
# Cast butget and gross columns into integer data types
int_df = movies_df.copy()
int_df[['budget', 'gross']] = int_df[['budget', 'gross']].astype(int)
int_df[['budget', 'gross']].dtypes
# Out:
# budget    int64
# gross     int64
# dtype: object

# %%
# Cast released column into datetime data type
time_df = int_df.copy()
time_df['released'] = pd.to_datetime(time_df['released'])
time_df['released'].dtype
# Out:
# dtype('<M8[ns]')

# %%
# Add a 'month' column
month_df = time_df.copy()
month_df['month'] = time_df['released'].dt.month
month_df.head(2)
# Out:
#     budget                     production country_kaggle     director  \
# 0  8000000  Columbia Pictures Corporation            USA   Rob Reiner
# 1  6000000             Paramount Pictures            USA  John Hughes
#
#   genre_kaggle     gross                      name rating   released  runtime  \
# 0    Adventure  52287414               Stand by Me      R 1986-08-22       89
# 1       Comedy  70136369  Ferris Bueller's Day Off  PG-13 1986-06-11      103
#
#    score_imdb        star_kaggle  votes_imdb writer_kaggle  year  \
# 0         8.1        Wil Wheaton      299174  Stephen King  1986
# 1         7.8  Matthew Broderick      264740   John Hughes  1986
#
#         genres_omdb                                       writers_omdb  \
# 0  Adventure, Drama  Stephen King (novel), Raynold Gideon (screenpl...
# 1            Comedy                                        John Hughes
#
#                                          actors_omdb  \
# 0  Wil Wheaton, River Phoenix, Corey Feldman, Jer...
# 1  Matthew Broderick, Alan Ruck, Mia Sara, Jeffre...
#
#                                                 plot    language_omdb  \
# 0  It's the summer of 1959 in Castlerock, Oregon ...          English
# 1  High school student Ferris Bueller wants a day...  English, German
#
#   country_omdb                                             awards  \
# 0          USA  Nominated for 1 Oscar. Another 5 wins & 10 nom...
# 1          USA      Nominated for 1 Golden Globe. Another 2 wins.
#
#                                               poster  score_metacritic   type  \
# 0  https://m.media-amazon.com/images/M/MV5BODJmY2...              75.0  movie
# 1  https://m.media-amazon.com/images/M/MV5BMDA0Nj...              61.0  movie
#
#    month
# 0      8
# 1      6

# %%
# Check dtypes again
month_df.dtypes
# Out:
# budget                       int64
# production                  object
# country_kaggle              object
# director                    object
# genre_kaggle                object
# gross                        int64
# name                        object
# rating                      object
# released            datetime64[ns]
# runtime                      int64
# score_imdb                 float64
# star_kaggle                 object
# votes_imdb                   int64
# writer_kaggle               object
# year                         int64
# genres_omdb                 object
# writers_omdb                object
# actors_omdb                 object
# plot                        object
# language_omdb               object
# country_omdb                object
# awards                      object
# poster                      object
# score_metacritic           float64
# type                        object
# month                        int64
# dtype: object

# %% [markdown]
# **We will also rearrange the orders of all the columns**

# %%
print(f'Column Names: {month_df.columns}')
print(f'Columns Count: {len(month_df.columns)}')
# Out:
# Column Names: Index(['budget', 'production', 'country_kaggle', 'director', 'genre_kaggle',
#        'gross', 'name', 'rating', 'released', 'runtime', 'score_imdb',
#        'star_kaggle', 'votes_imdb', 'writer_kaggle', 'year', 'genres_omdb',
#        'writers_omdb', 'actors_omdb', 'plot', 'language_omdb', 'country_omdb',
#        'awards', 'poster', 'score_metacritic', 'type', 'month'],
#       dtype='object')
# Columns Count: 26

# %%
ordered_df.head(1)
# Out:
#     budget                     production country_kaggle    director  \
# 0  8000000  Columbia Pictures Corporation            USA  Rob Reiner
#
#   genre_kaggle     gross         name rating   released  runtime  score_imdb  \
# 0    Adventure  52287414  Stand by Me      R 1986-08-22       89         8.1
#
#    star_kaggle  votes_imdb writer_kaggle  year       genres_omdb  \
# 0  Wil Wheaton      299174  Stephen King  1986  Adventure, Drama
#
#                                         writers_omdb  \
# 0  Stephen King (novel), Raynold Gideon (screenpl...
#
#                                          actors_omdb  \
# 0  Wil Wheaton, River Phoenix, Corey Feldman, Jer...
#
#                                                 plot language_omdb  \
# 0  It's the summer of 1959 in Castlerock, Oregon ...       English
#
#   country_omdb                                             awards  \
# 0          USA  Nominated for 1 Oscar. Another 5 wins & 10 nom...
#
#                                               poster  score_metacritic   type  \
# 0  https://m.media-amazon.com/images/M/MV5BODJmY2...              75.0  movie
#
#    month
# 0      8

# %%
# We will reorder all columns and also remove "poster" and "type" columns later
# The "poster" column could be a resource to pull poster pictures of movies
# The "type" column will be used to identify "non-movies" (series) to be removed
ordered_df = month_df[['name', 'production', 'director', 'runtime',
                       'released', 'year', 'month',
                       'country_kaggle', 'country_omdb',
                       'star_kaggle', 'actors_omdb',
                       'writer_kaggle', 'writers_omdb',
                       'language_omdb', 'plot', 'awards',
                       'score_imdb', 'votes_imdb', 'score_metacritic',
                       'budget', 'genre_kaggle',
                       'gross', 'genres_omdb', 'rating',
                       'poster', 'type'
                      ]]
len(ordered_df.columns)
# Out:
# 26

# %%
ordered_df.head(2)
# Out:
#                        name                     production     director  \
# 0               Stand by Me  Columbia Pictures Corporation   Rob Reiner
# 1  Ferris Bueller's Day Off             Paramount Pictures  John Hughes
#
#    runtime   released  year  month country_kaggle country_omdb  \
# 0       89 1986-08-22  1986      8            USA          USA
# 1      103 1986-06-11  1986      6            USA          USA
#
#          star_kaggle                                        actors_omdb  \
# 0        Wil Wheaton  Wil Wheaton, River Phoenix, Corey Feldman, Jer...
# 1  Matthew Broderick  Matthew Broderick, Alan Ruck, Mia Sara, Jeffre...
#
#   writer_kaggle                                       writers_omdb  \
# 0  Stephen King  Stephen King (novel), Raynold Gideon (screenpl...
# 1   John Hughes                                        John Hughes
#
#      language_omdb                                               plot  \
# 0          English  It's the summer of 1959 in Castlerock, Oregon ...
# 1  English, German  High school student Ferris Bueller wants a day...
#
#                                               awards  score_imdb  votes_imdb  \
# 0  Nominated for 1 Oscar. Another 5 wins & 10 nom...         8.1      299174
# 1      Nominated for 1 Golden Globe. Another 2 wins.         7.8      264740
#
#    score_metacritic   budget genre_kaggle     gross       genres_omdb rating  \
# 0              75.0  8000000    Adventure  52287414  Adventure, Drama      R
# 1              61.0  6000000       Comedy  70136369            Comedy  PG-13
#
#                                               poster   type
# 0  https://m.media-amazon.com/images/M/MV5BODJmY2...  movie
# 1  https://m.media-amazon.com/images/M/MV5BMDA0Nj...  movie

# %%
ordered_df['type'].value_counts()
# Out:
# movie     6386
# series      89
# Name: type, dtype: int64

# %%
# Remove "series" types from df
type_filter = ordered_df['type'] != 'series'
ordered_df = ordered_df.loc[type_filter]

# %%
# Now we remove "poster" and "type" columns as we no longer need them
cleaned_df = ordered_df.iloc[:, :-2]
cleaned_df.head(2)
# Out:
#                        name                     production     director  \
# 0               Stand by Me  Columbia Pictures Corporation   Rob Reiner
# 1  Ferris Bueller's Day Off             Paramount Pictures  John Hughes
#
#    runtime   released  year  month country_kaggle country_omdb  \
# 0       89 1986-08-22  1986      8            USA          USA
# 1      103 1986-06-11  1986      6            USA          USA
#
#          star_kaggle                                        actors_omdb  \
# 0        Wil Wheaton  Wil Wheaton, River Phoenix, Corey Feldman, Jer...
# 1  Matthew Broderick  Matthew Broderick, Alan Ruck, Mia Sara, Jeffre...
#
#   writer_kaggle                                       writers_omdb  \
# 0  Stephen King  Stephen King (novel), Raynold Gideon (screenpl...
# 1   John Hughes                                        John Hughes
#
#      language_omdb                                               plot  \
# 0          English  It's the summer of 1959 in Castlerock, Oregon ...
# 1  English, German  High school student Ferris Bueller wants a day...
#
#                                               awards  score_imdb  votes_imdb  \
# 0  Nominated for 1 Oscar. Another 5 wins & 10 nom...         8.1      299174
# 1      Nominated for 1 Golden Globe. Another 2 wins.         7.8      264740
#
#    score_metacritic   budget genre_kaggle     gross       genres_omdb rating
# 0              75.0  8000000    Adventure  52287414  Adventure, Drama      R
# 1              61.0  6000000       Comedy  70136369            Comedy  PG-13

# %%
# We will also reverse the order of the df by sorting it descending by year 
sorted_df = cleaned_df.copy()
sorted_df.sort_values(by=['name'], ascending=True, inplace=True)
sorted_df.sort_values(by=['year'], ascending=False, inplace=True)
sorted_df = sorted_df.reset_index(drop=True)
sorted_df.head()
# Out:
#                                         name                   production  \
# 0                                       Gold          Black Bear Pictures
# 1                                 The Choice  Nicholas Sparks Productions
# 2  Middle School: The Worst Years of My Life                    CBS Films
# 3                           Midnight Special                 Warner Bros.
# 4                            A Monster Calls        Apaches Entertainment
#
#          director  runtime   released  year  month country_kaggle  \
# 0  Stephen Gaghan      120 2017-01-27  2016      1            USA
# 1       Ross Katz      111 2016-02-05  2016      2            USA
# 2      Steve Carr       92 2016-10-07  2016     10            USA
# 3    Jeff Nichols      112 2016-04-21  2016      4            USA
# 4     J.A. Bayona      108 2017-01-06  2016      1             UK
#
#      country_omdb          star_kaggle  \
# 0             USA  Matthew McConaughey
# 1   United States      Benjamin Walker
# 2   USA, Cambodia        Griffin Gluck
# 3     USA, Greece      Michael Shannon
# 4  UK, Spain, USA     Lewis MacDougall
#
#                                          actors_omdb    writer_kaggle  \
# 0  Matthew McConaughey, Edgar Ramírez, Bryce Dall...  Patrick Massett
# 1  Benjamin Walker, Teresa Palmer, Alexandra Dadd...       Bryan Sipe
# 2  Griffin Gluck, Lauren Graham, Alexa Nisenson, ...     Chris Bowman
# 3  Michael Shannon, Joel Edgerton, Kirsten Dunst,...     Jeff Nichols
# 4  Lewis MacDougall, Sigourney Weaver, Felicity J...     Patrick Ness
#
#                                         writers_omdb        language_omdb  \
# 0                       Patrick Massett, John Zinman  English, Indonesian
# 1                        Bryan Sipe, Nicholas Sparks              English
# 2  Chris Bowman (screenplay by), Hubbel Palmer (s...       English, Khmer
# 3                                       Jeff Nichols              English
# 4  Patrick Ness (screenplay by), Patrick Ness (ba...              English
#
#                                                 plot  \
# 0  With the sudden death of his father, fourth-ge...
# 1  In a small coastal town, the veterinarian Trav...
# 2  Imaginative quiet teenager Rafe Katchadorian i...
# 3  Alton Meyer is a boy unlike any other in the w...
# 4  The monster does not come walking often. This ...
#
#                       awards  score_imdb  votes_imdb  score_metacritic  \
# 0     1 win & 5 nominations.         6.7       32147              49.0
# 1              3 nominations         6.6       22972              26.0
# 2             5 nominations.         6.1        4556              51.0
# 3   3 wins & 14 nominations.         6.7       58549              76.0
# 4  39 wins & 56 nominations.         7.5       49969              76.0
#
#      budget genre_kaggle     gross                        genres_omdb rating
# 0  20000000    Adventure   7222964                       Crime, Drama      R
# 1         0        Drama  18709066                     Drama, Romance  PG-13
# 2   8500000    Animation  19985196          Animation, Comedy, Family     PG
# 3  18000000        Drama   3707794   Drama, Mystery, Sci-Fi, Thriller  PG-13
# 4  43000000        Drama   3730982  Adventure, Drama, Family, Fantasy  PG-13

# %%
# Finally, we will also double check if there's any duplicated movie names
print(f"Duplicate values? {sorted_df['name'].duplicated().any()}")
print(f"How many? {sorted_df['name'].duplicated().sum()}")
# Out:
# Duplicate values? True
# How many? 89

# %%
# Visualize duplicated names to make decision on drop method
sorted_df[sorted_df['name'].duplicated(keep=False)].sort_values(by=['name']).head(10)
# Out:
#                      name                              production  \
# 4330        Anna Karenina        Icon Entertainment International
# 968         Anna Karenina                      Universal Pictures
# 3119          Bad Company                     Touchstone Pictures
# 4758          Bad Company                     Touchstone Pictures
# 855   Beautiful Creatures                     Alcon Entertainment
# 3658  Beautiful Creatures                 Arts Council of England
# 6609   Behind Enemy Lines                           Not specified
# 3345   Behind Enemy Lines  Twentieth Century Fox Film Corporation
# 2340          Black Sheep             New Zealand Film Commission
# 4405          Black Sheep                       Broadway Pictures
#
#                  director  runtime   released  year  month country_kaggle  \
# 4330         Bernard Rose      108 1997-04-04  1997      4            USA
# 968            Joe Wright      129 2013-03-01  2012      3             UK
# 3119      Joel Schumacher      116 2002-06-07  2002      6            USA
# 4758        Damian Harris      108 1995-01-20  1995      1            USA
# 855   Richard LaGravenese      124 2013-02-14  2013      2            USA
# 3658          Bill Eagles       86 2001-01-19  2000      1             UK
# 6609          Gideon Amir       90 1986-04-04  1986      4            USA
# 3345           John Moore      106 2001-11-30  2001     11            USA
# 2340        Jonathan King       87 2007-03-29  2006      3    New Zealand
# 4405    Penelope Spheeris       87 1996-02-02  1996      2            USA
#
#                   country_omdb      star_kaggle  \
# 4330            United Kingdom   Sophie Marceau
# 968             United Kingdom  Keira Knightley
# 3119       USA, Czech Republic  Anthony Hopkins
# 4758       USA, Czech Republic     Ellen Barkin
# 855                        USA    Alice Englert
# 3658                       USA     Rachel Weisz
# 6609                       USA  David Carradine
# 3345                       USA     Gene Hackman
# 2340  New Zealand, South Korea    Oliver Driver
# 4405  New Zealand, South Korea     Chris Farley
#
#                                             actors_omdb        writer_kaggle  \
# 4330    Keira Knightley, Jude Law, Aaron Taylor-Johnson          Leo Tolstoy
# 968     Keira Knightley, Jude Law, Aaron Taylor-Johnson         Tom Stoppard
# 3119  Anthony Hopkins, Chris Rock, Peter Stormare, G...      Gary M. Goodman
# 4758  Anthony Hopkins, Chris Rock, Peter Stormare, G...          Ross Thomas
# 855   Alden Ehrenreich, Alice Englert, Jeremy Irons,...  Richard LaGravenese
# 3658  Alden Ehrenreich, Alice Englert, Jeremy Irons,...         Simon Donald
# 6609  Owen Wilson, Gene Hackman, Gabriel Macht, Char...      Malcolm Barbour
# 3345  Owen Wilson, Gene Hackman, Gabriel Macht, Char...           Jim Thomas
# 2340         Oliver Driver, Nathan Meister, Tammy Davis        Jonathan King
# 4405         Oliver Driver, Nathan Meister, Tammy Davis            Fred Wolf
#
#                                            writers_omdb  \
# 4330                          Tom Stoppard, Lev Tolstoy
# 968                           Tom Stoppard, Lev Tolstoy
# 3119  Gary M. Goodman (story), David Himmelstein (st...
# 4758  Gary M. Goodman (story), David Himmelstein (st...
# 855   Richard LaGravenese (screenplay), Kami Garcia ...
# 3658  Richard LaGravenese (screenplay), Kami Garcia ...
# 6609  Jim Thomas (story), John Thomas (story), David...
# 3345  Jim Thomas (story), John Thomas (story), David...
# 2340                                      Jonathan King
# 4405                                      Jonathan King
#
#                                 language_omdb  \
# 4330                                  English
# 968                                   English
# 3119                                  English
# 4758                                  English
# 855                                   English
# 3658                                  English
# 6609  English, Serbo-Croatian, Spanish, Czech
# 3345  English, Serbo-Croatian, Spanish, Czech
# 2340                                  English
# 4405                                  English
#
#                                                    plot  \
# 4330  In 1874, in the Imperial Russia, the aristocra...
# 968   In 1874, in the Imperial Russia, the aristocra...
# 3119  When a CIA agent is killed during a nuclear ar...
# 4758  When a CIA agent is killed during a nuclear ar...
# 855   Teenager Ethan Wate is obsessed with his urge ...
# 3658  Teenager Ethan Wate is obsessed with his urge ...
# 6609  Fighter navigator Chris Burnett wants out: he ...
# 3345  Fighter navigator Chris Burnett wants out: he ...
# 2340  An experiment in genetic engineering turns har...
# 4405  An experiment in genetic engineering turns har...
#
#                                            awards  score_imdb  votes_imdb  \
# 4330  Won 1 Oscar. 33 wins & 53 nominations total         6.4        4851
# 968   Won 1 Oscar. 33 wins & 53 nominations total         6.6       77083
# 3119                                          NaN         5.6       41284
# 4758                                          NaN         5.4        2411
# 855                                9 nominations.         6.2       73570
# 3658                               9 nominations.         5.9        3150
# 6609                       1 win & 2 nominations.         4.9         368
# 3345                       1 win & 2 nominations.         6.4       90731
# 2340                       5 wins & 5 nominations         5.8       36120
# 4405                       5 wins & 5 nominations         6.2       31582
#
#       score_metacritic    budget genre_kaggle     gross  \
# 4330              63.0  35000000        Drama    791830
# 968               63.0         0        Drama  12816367
# 3119              37.0  70000000       Action  30160161
# 4758              37.0         0        Crime   3700000
# 855               52.0  60000000        Drama  19452138
# 3658              52.0         0       Comedy     55381
# 6609              49.0         0       Action   2497233
# 3345              49.0  40000000       Action  59068786
# 2340              62.0         0       Comedy     82987
# 4405              62.0         0       Comedy  32377000
#
#                        genres_omdb     rating
# 4330                Drama, Romance      PG-13
# 968                 Drama, Romance          R
# 3119      Action, Comedy, Thriller      PG-13
# 4758      Action, Comedy, Thriller          R
# 855        Drama, Fantasy, Romance      PG-13
# 3658       Drama, Fantasy, Romance          R
# 6609  Action, Drama, Thriller, War          R
# 3345  Action, Drama, Thriller, War      PG-13
# 2340        Comedy, Horror, Sci-Fi  NOT RATED
# 4405        Comedy, Horror, Sci-Fi      PG-13

# %%
# Remove all rows with duplicated movie names
final_df = sorted_df.copy()
final_df = final_df.drop_duplicates(subset=['name'], keep=False, ignore_index=True)
final_df.head()
# Out:
#                                         name                   production  \
# 0                                       Gold          Black Bear Pictures
# 1                                 The Choice  Nicholas Sparks Productions
# 2  Middle School: The Worst Years of My Life                    CBS Films
# 3                           Midnight Special                 Warner Bros.
# 4                            A Monster Calls        Apaches Entertainment
#
#          director  runtime   released  year  month country_kaggle  \
# 0  Stephen Gaghan      120 2017-01-27  2016      1            USA
# 1       Ross Katz      111 2016-02-05  2016      2            USA
# 2      Steve Carr       92 2016-10-07  2016     10            USA
# 3    Jeff Nichols      112 2016-04-21  2016      4            USA
# 4     J.A. Bayona      108 2017-01-06  2016      1             UK
#
#      country_omdb          star_kaggle  \
# 0             USA  Matthew McConaughey
# 1   United States      Benjamin Walker
# 2   USA, Cambodia        Griffin Gluck
# 3     USA, Greece      Michael Shannon
# 4  UK, Spain, USA     Lewis MacDougall
#
#                                          actors_omdb    writer_kaggle  \
# 0  Matthew McConaughey, Edgar Ramírez, Bryce Dall...  Patrick Massett
# 1  Benjamin Walker, Teresa Palmer, Alexandra Dadd...       Bryan Sipe
# 2  Griffin Gluck, Lauren Graham, Alexa Nisenson, ...     Chris Bowman
# 3  Michael Shannon, Joel Edgerton, Kirsten Dunst,...     Jeff Nichols
# 4  Lewis MacDougall, Sigourney Weaver, Felicity J...     Patrick Ness
#
#                                         writers_omdb        language_omdb  \
# 0                       Patrick Massett, John Zinman  English, Indonesian
# 1                        Bryan Sipe, Nicholas Sparks              English
# 2  Chris Bowman (screenplay by), Hubbel Palmer (s...       English, Khmer
# 3                                       Jeff Nichols              English
# 4  Patrick Ness (screenplay by), Patrick Ness (ba...              English
#
#                                                 plot  \
# 0  With the sudden death of his father, fourth-ge...
# 1  In a small coastal town, the veterinarian Trav...
# 2  Imaginative quiet teenager Rafe Katchadorian i...
# 3  Alton Meyer is a boy unlike any other in the w...
# 4  The monster does not come walking often. This ...
#
#                       awards  score_imdb  votes_imdb  score_metacritic  \
# 0     1 win & 5 nominations.         6.7       32147              49.0
# 1              3 nominations         6.6       22972              26.0
# 2             5 nominations.         6.1        4556              51.0
# 3   3 wins & 14 nominations.         6.7       58549              76.0
# 4  39 wins & 56 nominations.         7.5       49969              76.0
#
#      budget genre_kaggle     gross                        genres_omdb rating
# 0  20000000    Adventure   7222964                       Crime, Drama      R
# 1         0        Drama  18709066                     Drama, Romance  PG-13
# 2   8500000    Animation  19985196          Animation, Comedy, Family     PG
# 3  18000000        Drama   3707794   Drama, Mystery, Sci-Fi, Thriller  PG-13
# 4  43000000        Drama   3730982  Adventure, Drama, Family, Fantasy  PG-13

# %%
len(final_df)
# Out:
# 6555

# %%
# Export final_df to CSV
final_df.to_csv('../resources/cleaned_data/movies_complete_cleaned.csv', index=False)
